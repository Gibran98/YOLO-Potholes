# %% [markdown]
# # Entrenamiento de modelo de detección de objetos con YOLOv4 para baches

# %% [markdown]
# ## Montamos el Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Nos dirigimos al path donde está la carpeta de yolov4_training

# %%
# %cd /content/drive/MyDrive/Proyecto_final/yolov4_training
# %ls
# Out:
# /content/drive/MyDrive/Proyecto_final/yolov4_training
# config/   data/            README.md          utils/
# darknet/  prev_trainings/  train_detector.sh  yolov4/

# %% [markdown]
# Nos aseguramos de que el archivo config esté correcto principalmente el path y clase.

# %%
# !cat config/config.ini
# Out:
# [YOLO]
# # list_clases should be in alphabetic order
# list_classes = ["pothole"]
# # root_path/data must inlcude obj and test folders
# root_path = /content/drive/MyDrive/Proyecto_final/yolov4_training
# batch = 64
# subdivisions = 32
# width = 416
# height = 416

# %%
# !cat train_detector.sh

# %% [markdown]
# Entrenamos el modelo con tan solo correr la siguiente celda, ya que se ha automatizado en la carpeta actual para ser entrenado un modelo de detección de objetos. Solo falta esperar a que termine y se convierten los pesos.

# %%
# %%shell
#
# bash train_detector.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#  Tensor Cores are disabled until the first 3000 iterations are reached.
#  Last accuracy mAP@0.50 = 88.11 %, best = 88.11 %
#  1040: 2.859467, 2.361015 avg loss, 0.001000 rate, 11.655310 seconds, 66560 images, 2.015864 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000050 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.731955), count: 24, class_loss = 6.788199, iou_loss = 74.123337, total_loss = 80.911537
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.784263), count: 25, class_loss = 7.695408, iou_loss = 13.084576, total_loss = 20.779984
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.810879), count: 9, class_loss = 3.153430, iou_loss = 1.019469, total_loss = 4.172899
# ...
